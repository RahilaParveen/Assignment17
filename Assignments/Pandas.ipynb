# %%
import pandas as pd

# %%
aList = [[1,2,3],[4,5,6]]

# %%
df = pd.DataFrame(aList)

# %%
df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
df.columns=['a','b','c']

# %%
df
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6

# %%
df.describe()
# Out:
#              a        b        c
# count  2.00000  2.00000  2.00000
# mean   2.50000  3.50000  4.50000
# std    2.12132  2.12132  2.12132
# min    1.00000  2.00000  3.00000
# 25%    1.75000  2.75000  3.75000
# 50%    2.50000  3.50000  4.50000
# 75%    3.25000  4.25000  5.25000
# max    4.00000  5.00000  6.00000

# %%
df.a
# Out:
# 0    1
# 1    4
# Name: a, dtype: int64

# %%
df.a.dtypes
# Out:
# dtype('int64')

# %%
df.dtypes
# Out:
# a    int64
# b    int64
# c    int64
# dtype: object

# %%
df['a']
# Out:
# 0    1
# 1    4
# Name: a, dtype: int64

# %%
type(df['a'])
# Out:
# pandas.core.series.Series

# %%
df[['a']]
# Out:
#    a
# 0  1
# 1  4

# %%
type(df[['a']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['a','c']]
# Out:
#    a  c
# 0  1  3
# 1  4  6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
# a    2 non-null int64
# b    2 non-null int64
# c    2 non-null int64
# dtypes: int64(3)
# memory usage: 176.0 bytes

# %%
df.describe()
# Out:
#              a        b        c
# count  2.00000  2.00000  2.00000
# mean   2.50000  3.50000  4.50000
# std    2.12132  2.12132  2.12132
# min    1.00000  2.00000  3.00000
# 25%    1.75000  2.75000  3.75000
# 50%    2.50000  3.50000  4.50000
# 75%    3.25000  4.25000  5.25000
# max    4.00000  5.00000  6.00000

# %%
newList = [1,2,3]

# %%
newdf = pd.DataFrame(newList)

# %%
newdf
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
surveys = pd.read_csv('./surveys.csv', index_col='record_id')

# %%
surveys.head()
# Out:
#            month  day  year  plot_id species_id sex  hindfoot_length  weight
# record_id
# 1              7   16  1977        2         NL   M             32.0     NaN
# 2              7   16  1977        3         NL   M             33.0     NaN
# 3              7   16  1977        2         DM   F             37.0     NaN
# 4              7   16  1977        7         DM   M             36.0     NaN
# 5              7   16  1977        3         DM   M             35.0     NaN

# %%
surveys.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35549 entries, 1 to 35549
# Data columns (total 8 columns):
# month              35549 non-null int64
# day                35549 non-null int64
# year               35549 non-null int64
# plot_id            35549 non-null int64
# species_id         34786 non-null object
# sex                33038 non-null object
# hindfoot_length    31438 non-null float64
# weight             32283 non-null float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 2.4+ MB

# %%
surveys.describe()
# Out:
#               month           day          year       plot_id  \
# count  35549.000000  35549.000000  35549.000000  35549.000000
# mean       6.477847     15.991195   1990.475231     11.397001
# std        3.396925      8.257366      7.493355      6.799406
# min        1.000000      1.000000   1977.000000      1.000000
# 25%        4.000000      9.000000   1984.000000      5.000000
# 50%        6.000000     16.000000   1990.000000     11.000000
# 75%       10.000000     23.000000   1997.000000     17.000000
# max       12.000000     31.000000   2002.000000     24.000000
#
#        hindfoot_length        weight
# count     31438.000000  32283.000000
# mean         29.287932     42.672428
# std           9.564759     36.631259
# min           2.000000      4.000000
# 25%          21.000000     20.000000
# 50%          32.000000     37.000000
# 75%          36.000000     48.000000
# max          70.000000    280.000000

# %%
surveys.columns
# Out:
# Index(['month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
pd.unique(surveys['year'])
# Out:
# array([1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987,
#        1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998,
#        1999, 2000, 2001, 2002])

# %%
grouped_data = surveys.groupby('year')

# %%
grouped_data.head()
# Out:
#            month  day  year  plot_id species_id  sex  hindfoot_length  weight
# record_id
# 1              7   16  1977        2         NL    M             32.0     NaN
# 2              7   16  1977        3         NL    M             33.0     NaN
# 3              7   16  1977        2         DM    F             37.0     NaN
# 4              7   16  1977        7         DM    M             36.0     NaN
# 5              7   16  1977        3         DM    M             35.0     NaN
# ...          ...  ...   ...      ...        ...  ...              ...     ...
# 33321          1   12  2002        1         DM    M             38.0    44.0
# 33322          1   12  2002        1         DO    M             37.0    58.0
# 33323          1   12  2002        1         PB    M             28.0    45.0
# 33324          1   12  2002        1         AB  NaN              NaN     NaN
# 33325          1   12  2002        1         DO    M             35.0    29.0
#
# [130 rows x 8 columns]

# %%
grouped_data.count()
# Out:
#       month   day  plot_id  species_id   sex  hindfoot_length  weight
# year
# 1977    503   503      503         487   418              408     266
# 1978   1048  1048     1048         992   936              857     868
# 1979    719   719      719         658   651              604     638
# 1980   1415  1415     1415        1375  1332              963    1317
# 1981   1472  1472     1472        1417  1376             1043    1358
# 1982   1978  1978     1978        1964  1850             1560    1841
# 1983   1673  1673     1673        1652  1568             1559    1556
# 1984    981   981      981         951   888              878     880
# 1985   1438  1438     1438        1416  1352             1345    1326
# 1986    942   942      942         922   869              853     853
# 1987   1671  1671     1671        1668  1539             1377    1517
# 1988   1469  1469     1469        1457  1341             1332    1327
# ...

# %%
grouped_data.min()
# Out:
#       month  day  plot_id  hindfoot_length  weight
# year
# 1977      7   10        1              9.0     4.0
# 1978      1    2        1             13.0     6.0
# 1979      1    3        1             12.0     6.0
# 1980      1    2        1             14.0     5.0
# 1981      1    1        1             11.0     4.0
# 1982      1    1        1              8.0     4.0
# 1983      1    8        1             14.0     4.0
# 1984      2    1        1             12.0     7.0
# 1985      1    7        1              6.0     4.0
# 1986      3    3        1             14.0     7.0
# 1987      1    1        1             11.0     5.0
# 1988      1    5        1             11.0     7.0
# 1989      1    1        1             11.0     5.0
# 1990      1    6        1             13.0     6.0
# 1991      1    7        1              7.0     5.0
# 1992      1    2        1              6.0     6.0
# 1993      1   13        1              7.0     5.0
# ...

# %%
grouped_data.max()
# Out:
#       month  day  plot_id  hindfoot_length  weight
# year
# 1977     12   21       23             54.0   149.0
# 1978     12   20       23             55.0   232.0
# 1979     11   31       24             58.0   274.0
# 1980     12   27       24             55.0   243.0
# 1981     12   31       24             57.0   264.0
# 1982     11   30       24             54.0   252.0
# 1983     12   27       24             54.0   256.0
# 1984     12   31       24             53.0   259.0
# 1985     12   24       24             70.0   225.0
# 1986     12   16       24             54.0   240.0
# 1987     11   31       24             56.0   278.0
# 1988     12   24       24             55.0   248.0
# 1989     12   30       24             54.0   275.0
# 1990     12   30       24             55.0   243.0
# 1991     12   21       24             54.0   199.0
# 1992     12   31       24             52.0   220.0
# 1993     12   26       24             51.0   233.0
# ...

# %%
surveys[['species_id']]
# Out:
#           species_id
# record_id
# 1                 NL
# 2                 NL
# 3                 DM
# 4                 DM
# 5                 DM
# ...              ...
# 35545             AH
# 35546             AH
# 35547             RM
# 35548             DO
# 35549            NaN
#
# [35549 rows x 1 columns]

# %%
surveys.head()
# Out:
#            month  day  year  plot_id species_id sex  hindfoot_length  weight
# record_id
# 1              7   16  1977        2         NL   M             32.0     NaN
# 2              7   16  1977        3         NL   M             33.0     NaN
# 3              7   16  1977        2         DM   F             37.0     NaN
# 4              7   16  1977        7         DM   M             36.0     NaN
# 5              7   16  1977        3         DM   M             35.0     NaN

# %%
surveys.iloc[:,:]
# Out:
#            month  day  year  plot_id species_id  sex  hindfoot_length  weight
# record_id
# 1              7   16  1977        2         NL    M             32.0     NaN
# 2              7   16  1977        3         NL    M             33.0     NaN
# 3              7   16  1977        2         DM    F             37.0     NaN
# 4              7   16  1977        7         DM    M             36.0     NaN
# 5              7   16  1977        3         DM    M             35.0     NaN
# ...          ...  ...   ...      ...        ...  ...              ...     ...
# 35545         12   31  2002       15         AH  NaN              NaN     NaN
# 35546         12   31  2002       15         AH  NaN              NaN     NaN
# 35547         12   31  2002       10         RM    F             15.0    14.0
# 35548         12   31  2002        7         DO    M             36.0    51.0
# 35549         12   31  2002        5        NaN  NaN              NaN     NaN
#
# ...

# %%
surveys.iloc[:2,:]
# Out:
#            month  day  year  plot_id species_id sex  hindfoot_length  weight
# record_id
# 1              7   16  1977        2         NL   M             32.0     NaN
# 2              7   16  1977        3         NL   M             33.0     NaN

# %%
surveys.iloc[:2,-2:]
# Out:
#            hindfoot_length  weight
# record_id
# 1                     32.0     NaN
# 2                     33.0     NaN

# %%
surveys.iloc[-5:, :3]
# Out:
#            month  day  year
# record_id
# 35545         12   31  2002
# 35546         12   31  2002
# 35547         12   31  2002
# 35548         12   31  2002
# 35549         12   31  2002

# %%
surveys.iloc[0:3, 0:3]
# Out:
#            month  day  year
# record_id
# 1              7   16  1977
# 2              7   16  1977
# 3              7   16  1977

# %%
surveys.iloc[51:52, :1]
# Out:
#            month
# record_id
# 52             7

# %%
surveys
# Out:
#            month  day  year  plot_id species_id  sex  hindfoot_length  weight
# record_id
# 1              7   16  1977        2         NL    M             32.0     NaN
# 2              7   16  1977        3         NL    M             33.0     NaN
# 3              7   16  1977        2         DM    F             37.0     NaN
# 4              7   16  1977        7         DM    M             36.0     NaN
# 5              7   16  1977        3         DM    M             35.0     NaN
# ...          ...  ...   ...      ...        ...  ...              ...     ...
# 35545         12   31  2002       15         AH  NaN              NaN     NaN
# 35546         12   31  2002       15         AH  NaN              NaN     NaN
# 35547         12   31  2002       10         RM    F             15.0    14.0
# 35548         12   31  2002        7         DO    M             36.0    51.0
# 35549         12   31  2002        5        NaN  NaN              NaN     NaN
#
# ...

# %%
surveys.iloc[0:5,2:3]
# Out:
#            year
# record_id
# 1          1977
# 2          1977
# 3          1977
# 4          1977
# 5          1977

# %%
surveys.iloc[30:31,3:5]
# Out:
#            plot_id species_id
# record_id
# 31              15         DM

# %%
surveys.describe()
# Out:
#               month           day          year       plot_id  \
# count  35549.000000  35549.000000  35549.000000  35549.000000
# mean       6.477847     15.991195   1990.475231     11.397001
# std        3.396925      8.257366      7.493355      6.799406
# min        1.000000      1.000000   1977.000000      1.000000
# 25%        4.000000      9.000000   1984.000000      5.000000
# 50%        6.000000     16.000000   1990.000000     11.000000
# 75%       10.000000     23.000000   1997.000000     17.000000
# max       12.000000     31.000000   2002.000000     24.000000
#
#        hindfoot_length        weight
# count     31438.000000  32283.000000
# mean         29.287932     42.672428
# std           9.564759     36.631259
# min           2.000000      4.000000
# 25%          21.000000     20.000000
# 50%          32.000000     37.000000
# 75%          36.000000     48.000000
# max          70.000000    280.000000

# %%
surveys[surveys.year == 2000]
# Out:
#            month  day  year  plot_id species_id  sex  hindfoot_length  weight
# record_id
# 30159          1    8  2000        1         PP    F             22.0    17.0
# 30160          1    8  2000        1         DO    M             35.0    53.0
# 30161          1    8  2000        1         PP    F             21.0    17.0
# 30162          1    8  2000        1         DM    M             36.0    50.0
# 30163          1    8  2000        1         PP    M             20.0    16.0
# ...          ...  ...   ...      ...        ...  ...              ...     ...
# 31706         12   23  2000       15         OT    F             21.0    25.0
# 31707         12   23  2000       15         OT    M             20.0    19.0
# 31708         12   23  2000        5        NaN  NaN              NaN     NaN
# 31709         12   23  2000       10        NaN  NaN              NaN     NaN
# 31710         12   23  2000       16        NaN  NaN              NaN     NaN
#
# [1552 rows x 8 columns]

# %%
surveys[surveys.year < 2000]
# Out:
#            month  day  year  plot_id species_id  sex  hindfoot_length  weight
# record_id
# 1              7   16  1977        2         NL    M             32.0     NaN
# 2              7   16  1977        3         NL    M             33.0     NaN
# 3              7   16  1977        2         DM    F             37.0     NaN
# 4              7   16  1977        7         DM    M             36.0     NaN
# 5              7   16  1977        3         DM    M             35.0     NaN
# ...          ...  ...   ...      ...        ...  ...              ...     ...
# 30154         12    6  1999       15         PP    F             20.0    13.0
# 30155         12    6  1999       16         RM    F             16.0    14.0
# 30156         12    6  1999        5        NaN  NaN              NaN     NaN
# 30157         12    6  1999        7        NaN  NaN              NaN     NaN
# 30158         12    6  1999       10        NaN  NaN              NaN     NaN
#
# ...

# %%
surveys[surveys.year <= 2000]
# Out:
#            month  day  year  plot_id species_id  sex  hindfoot_length  weight
# record_id
# 1              7   16  1977        2         NL    M             32.0     NaN
# 2              7   16  1977        3         NL    M             33.0     NaN
# 3              7   16  1977        2         DM    F             37.0     NaN
# 4              7   16  1977        7         DM    M             36.0     NaN
# 5              7   16  1977        3         DM    M             35.0     NaN
# ...          ...  ...   ...      ...        ...  ...              ...     ...
# 31706         12   23  2000       15         OT    F             21.0    25.0
# 31707         12   23  2000       15         OT    M             20.0    19.0
# 31708         12   23  2000        5        NaN  NaN              NaN     NaN
# 31709         12   23  2000       10        NaN  NaN              NaN     NaN
# 31710         12   23  2000       16        NaN  NaN              NaN     NaN
#
# ...

# %%
df2k = surveys[surveys.year == 2000]

# %%
df2k[['year','species_id']]
# Out:
#            year species_id
# record_id
# 30159      2000         PP
# 30160      2000         DO
# 30161      2000         PP
# 30162      2000         DM
# 30163      2000         PP
# ...         ...        ...
# 31706      2000         OT
# 31707      2000         OT
# 31708      2000        NaN
# 31709      2000        NaN
# 31710      2000        NaN
#
# [1552 rows x 2 columns]

# %%
df2k[(df2k.month == 12) & (df2k.day == 23)]
# Out:
#            month  day  year  plot_id species_id  sex  hindfoot_length  weight
# record_id
# 31667         12   23  2000        3         PB    M             26.0    42.0
# 31668         12   23  2000        3         PB  NaN              NaN     NaN
# 31669         12   23  2000        3         PB    F             25.0    30.0
# 31670         12   23  2000        3         PB    M             26.0    28.0
# 31671         12   23  2000        3         OT    M             21.0    29.0
# 31672         12   23  2000        3         PB    M             26.0    35.0
# 31673         12   23  2000        4         DM    M             35.0    54.0
# 31674         12   23  2000        4         DM    M             35.0    48.0
# 31675         12   23  2000        4         PB    M             27.0    32.0
# 31676         12   23  2000        4         OT    M             21.0    24.0
# 31677         12   23  2000        4         OT    F             20.0    25.0
# ...

# %%
df2k[(df2k.month == 12) & (df2k.day == 23) & (df2k.species_id == 'OT')]
# Out:
#            month  day  year  plot_id species_id sex  hindfoot_length  weight
# record_id
# 31671         12   23  2000        3         OT   M             21.0    29.0
# 31676         12   23  2000        4         OT   M             21.0    24.0
# 31677         12   23  2000        4         OT   F             20.0    25.0
# 31678         12   23  2000        6         OT   M             21.0    22.0
# 31680         12   23  2000        6         OT   F             20.0    24.0
# 31681         12   23  2000        6         OT   M             20.0    21.0
# 31682         12   23  2000        6         OT   F             21.0    23.0
# 31687         12   23  2000       11         OT   F             21.0    25.0
# 31693         12   23  2000        8         OT   M             19.0    24.0
# 31695         12   23  2000        8         OT   F             20.0    21.0
# 31696         12   23  2000        8         OT   M             19.0    21.0
# ...

# %%
df2k[(df2k.month == 12) & (df2k.day == 23) & (df2k.species_id.isin(['OT','PB']))]
# Out:
#            month  day  year  plot_id species_id  sex  hindfoot_length  weight
# record_id
# 31667         12   23  2000        3         PB    M             26.0    42.0
# 31668         12   23  2000        3         PB  NaN              NaN     NaN
# 31669         12   23  2000        3         PB    F             25.0    30.0
# 31670         12   23  2000        3         PB    M             26.0    28.0
# 31671         12   23  2000        3         OT    M             21.0    29.0
# 31672         12   23  2000        3         PB    M             26.0    35.0
# 31675         12   23  2000        4         PB    M             27.0    32.0
# 31676         12   23  2000        4         OT    M             21.0    24.0
# 31677         12   23  2000        4         OT    F             20.0    25.0
# 31678         12   23  2000        6         OT    M             21.0    22.0
# 31679         12   23  2000        6         PB    F             26.0    31.0
# ...

# %%
df2k[(df2k.month == 12) & \
     (df2k.day == 23) & \
     (df2k.species_id.isin(['OT','PB']))]
# Out:
#            month  day  year  plot_id species_id  sex  hindfoot_length  weight
# record_id
# 31667         12   23  2000        3         PB    M             26.0    42.0
# 31668         12   23  2000        3         PB  NaN              NaN     NaN
# 31669         12   23  2000        3         PB    F             25.0    30.0
# 31670         12   23  2000        3         PB    M             26.0    28.0
# 31671         12   23  2000        3         OT    M             21.0    29.0
# 31672         12   23  2000        3         PB    M             26.0    35.0
# 31675         12   23  2000        4         PB    M             27.0    32.0
# 31676         12   23  2000        4         OT    M             21.0    24.0
# 31677         12   23  2000        4         OT    F             20.0    25.0
# 31678         12   23  2000        6         OT    M             21.0    22.0
# 31679         12   23  2000        6         PB    F             26.0    31.0
# ...

# %%
df2k[(df2k.species_id=='DO') | (df2k.species_id=='DM')]
# Out:
#            month  day  year  plot_id species_id sex  hindfoot_length  weight
# record_id
# 30160          1    8  2000        1         DO   M             35.0    53.0
# 30162          1    8  2000        1         DM   M             36.0    50.0
# 30167          1    8  2000        1         DO   M             35.0    41.0
# 30171          1    8  2000        2         DO   M             36.0    52.0
# 30173          1    8  2000        2         DO   F             35.0    54.0
# ...          ...  ...   ...      ...        ...  ..              ...     ...
# 31697         12   23  2000        8         DO   M             35.0    47.0
# 31698         12   23  2000        8         DO   M             36.0    46.0
# 31703         12   23  2000       14         DM   F             34.0     NaN
# 31704         12   23  2000       14         DM   M             35.0    52.0
# 31705         12   23  2000       14         DM   F             35.0    39.0
#
# [324 rows x 8 columns]

# %%
df2k[(df2k.month == 12) & \
     (df2k.day == 23) & \
     ((df2k.species_id == 'OT') | (df2k.species_id =='PB'))]
# Out:
#            month  day  year  plot_id species_id  sex  hindfoot_length  weight
# record_id
# 31667         12   23  2000        3         PB    M             26.0    42.0
# 31668         12   23  2000        3         PB  NaN              NaN     NaN
# 31669         12   23  2000        3         PB    F             25.0    30.0
# 31670         12   23  2000        3         PB    M             26.0    28.0
# 31671         12   23  2000        3         OT    M             21.0    29.0
# 31672         12   23  2000        3         PB    M             26.0    35.0
# 31675         12   23  2000        4         PB    M             27.0    32.0
# 31676         12   23  2000        4         OT    M             21.0    24.0
# 31677         12   23  2000        4         OT    F             20.0    25.0
# 31678         12   23  2000        6         OT    M             21.0    22.0
# 31679         12   23  2000        6         PB    F             26.0    31.0
# ...

# %% [markdown]
# ### convert datatype of column

# %%
df2k['cyear']=df2k['year'].astype(str)
# Out:
# /Users/akaghzi/Projects/Python/datascience/iba/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
myFloat = 1.3
print(int(myFloat))
# Out:
# 1

# %%
df2k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1552 entries, 30159 to 31710
# Data columns (total 9 columns):
# month              1552 non-null int64
# day                1552 non-null int64
# year               1552 non-null int64
# plot_id            1552 non-null int64
# species_id         1509 non-null object
# sex                1469 non-null object
# hindfoot_length    1465 non-null float64
# weight             1442 non-null float64
# cyear              1552 non-null object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 121.2+ KB

# %% [markdown]
# ### find values with NaN

# %%
df2k[df2k.sex.isna()]
# Out:
#            month  day  year  plot_id species_id  sex  hindfoot_length  weight  \
# record_id
# 30189          1    8  2000       18         AH  NaN              NaN     NaN
# 30195          1    8  2000       18         SS  NaN              NaN     NaN
# 30217          1    8  2000       23         AH  NaN              NaN     NaN
# 30218          1    8  2000        7         AH  NaN              NaN     NaN
# 30274          1   10  2000       14         AH  NaN              NaN     NaN
# ...          ...  ...   ...      ...        ...  ...              ...     ...
# 31668         12   23  2000        3         PB  NaN              NaN     NaN
# 31689         12   23  2000        9         AH  NaN              NaN     NaN
# 31708         12   23  2000        5        NaN  NaN              NaN     NaN
# 31709         12   23  2000       10        NaN  NaN              NaN     NaN
# 31710         12   23  2000       16        NaN  NaN              NaN     NaN
#
#           cyear
# ...

# %%
df2k[df2k.species_id.isna()].count()
# Out:
# month              43
# day                43
# year               43
# plot_id            43
# species_id          0
# sex                 0
# hindfoot_length     0
# weight              0
# cyear              43
# dtype: int64

# %%
df2k[(df2k.sex.isna()) & (df2k.species_id.isna())]
# Out:
#            month  day  year  plot_id species_id  sex  hindfoot_length  weight  \
# record_id
# 30283          1   10  2000       10        NaN  NaN              NaN     NaN
# 30357          2    5  2000       23        NaN  NaN              NaN     NaN
# 30420          2    6  2000        5        NaN  NaN              NaN     NaN
# 30421          2    6  2000       10        NaN  NaN              NaN     NaN
# 30500          3    4  2000       23        NaN  NaN              NaN     NaN
# 30580          3    5  2000        5        NaN  NaN              NaN     NaN
# 30581          3    5  2000       10        NaN  NaN              NaN     NaN
# 30720          5    1  2000        5        NaN  NaN              NaN     NaN
# 30721          5    1  2000        7        NaN  NaN              NaN     NaN
# 30722          5    1  2000       10        NaN  NaN              NaN     NaN
# 30723          5    1  2000       16        NaN  NaN              NaN     NaN
# ...

# %%
df2k[~df2k.sex.isna()]
# Out:
#            month  day  year  plot_id species_id sex  hindfoot_length  weight  \
# record_id
# 30159          1    8  2000        1         PP   F             22.0    17.0
# 30160          1    8  2000        1         DO   M             35.0    53.0
# 30161          1    8  2000        1         PP   F             21.0    17.0
# 30162          1    8  2000        1         DM   M             36.0    50.0
# 30163          1    8  2000        1         PP   M             20.0    16.0
# ...          ...  ...   ...      ...        ...  ..              ...     ...
# 31703         12   23  2000       14         DM   F             34.0     NaN
# 31704         12   23  2000       14         DM   M             35.0    52.0
# 31705         12   23  2000       14         DM   F             35.0    39.0
# 31706         12   23  2000       15         OT   F             21.0    25.0
# 31707         12   23  2000       15         OT   M             20.0    19.0
#
#           cyear
# record_id
# ...

# %%
df2k[df2k.sex.notna()]
# Out:
#            month  day  year  plot_id species_id sex  hindfoot_length  weight  \
# record_id
# 30159          1    8  2000        1         PP   F             22.0    17.0
# 30160          1    8  2000        1         DO   M             35.0    53.0
# 30161          1    8  2000        1         PP   F             21.0    17.0
# 30162          1    8  2000        1         DM   M             36.0    50.0
# 30163          1    8  2000        1         PP   M             20.0    16.0
# ...          ...  ...   ...      ...        ...  ..              ...     ...
# 31703         12   23  2000       14         DM   F             34.0     NaN
# 31704         12   23  2000       14         DM   M             35.0    52.0
# 31705         12   23  2000       14         DM   F             35.0    39.0
# 31706         12   23  2000       15         OT   F             21.0    25.0
# 31707         12   23  2000       15         OT   M             20.0    19.0
#
#           cyear
# record_id
# ...

# %%
df2k['weight'] = df2k.weight.fillna(42.67)
# Out:
# /Users/akaghzi/Projects/Python/datascience/iba/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2k.describe()
# Out:
#              month          day    year      plot_id  hindfoot_length  \
# count  1552.000000  1552.000000  1552.0  1552.000000      1465.000000
# mean      6.242268    12.634021  2000.0    11.091495        26.130375
# std       3.200067    10.939377     0.0     6.842476         5.726347
# min       1.000000     1.000000  2000.0     1.000000         2.000000
# 25%       3.000000     3.000000  2000.0     4.000000        22.000000
# 50%       7.000000     6.000000  2000.0    11.000000        25.000000
# 75%       8.000000    25.000000  2000.0    17.000000        27.000000
# max      12.000000    30.000000  2000.0    24.000000        64.000000
#
#             weight
# count  1552.000000
# mean     33.122874
# std      22.925095
# min       8.000000
# 25%      21.000000
# 50%      30.000000
# 75%      42.000000
# max     265.000000

# %%
df2k.to_csv('df2k.csv')

# %%
# df2k = pd.DataFrame([])

# %%
df2k
# Out:
#            month  day  year  plot_id species_id  sex  hindfoot_length  weight  \
# record_id
# 30159          1    8  2000        1         PP    F             22.0   17.00
# 30160          1    8  2000        1         DO    M             35.0   53.00
# 30161          1    8  2000        1         PP    F             21.0   17.00
# 30162          1    8  2000        1         DM    M             36.0   50.00
# 30163          1    8  2000        1         PP    M             20.0   16.00
# ...          ...  ...   ...      ...        ...  ...              ...     ...
# 31706         12   23  2000       15         OT    F             21.0   25.00
# 31707         12   23  2000       15         OT    M             20.0   19.00
# 31708         12   23  2000        5        NaN  NaN              NaN   42.67
# 31709         12   23  2000       10        NaN  NaN              NaN   42.67
# 31710         12   23  2000       16        NaN  NaN              NaN   42.67
#
#           cyear
# ...

# %%
hfl = df2k[(df2k.species_id=="PP") & (df2k.sex=="M")].iloc[:20,6:7]

# %%
hfl
# Out:
#            hindfoot_length
# record_id
# 30163                 20.0
# 30166                 23.0
# 30170                 21.0
# 30178                 24.0
# 30184                 21.0
# 30198                 22.0
# 30206                 20.0
# 30208                 22.0
# 30225                 22.0
# 30231                 23.0
# 30235                 23.0
# 30236                 22.0
# 30237                 22.0
# 30240                 19.0
# 30245                 21.0
# 30256                 23.0
# 30270                 19.0
# 30272                 19.0
# 30278                 21.0
# 30285                 24.0

# %%
# %matplotlib inline

# %%
hfl.plot()

# %%
import matplotlib.pyplot as plt

# %%
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]

# %%
gdp = [300, 543, 1075, 2862, 5979, 10289, 14958]

# %%
# plt.plot(years, gdp, color='green', marker='o', linestyle='solid')

# %%
# plt.title('gdp - nominal')

# %%
# plt.ylabel('billions of $')

# %%
# plt.show()

# %%
# plt.plot(years, gdp, color='green', marker='o', linestyle='solid')

# %%
plt.ylabel('billions of $')
plt.title('gdp - nominal')
# plt.legend()
plt.xlabel("years")
plt.plot(years, gdp, color='green', marker='o', linestyle='solid')

# %% [markdown]
# ### drop missing values from a column

# %%
df2k.dropna(subset=['hindfoot_length'],inplace=True)
# df2k.dropna()
# Out:
# /Users/akaghzi/Projects/Python/datascience/iba/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2k.describe()
# Out:
#              month          day    year      plot_id  hindfoot_length  \
# count  1465.000000  1465.000000  1465.0  1465.000000      1465.000000
# mean      6.249147    12.651877  2000.0    10.992491        26.130375
# std       3.203915    10.965310     0.0     6.857991         5.726347
# min       1.000000     1.000000  2000.0     1.000000         2.000000
# 25%       3.000000     3.000000  2000.0     4.000000        22.000000
# 50%       7.000000     6.000000  2000.0    11.000000        25.000000
# 75%       8.000000    25.000000  2000.0    17.000000        27.000000
# max      12.000000    30.000000  2000.0    24.000000        64.000000
#
#             weight
# count  1465.000000
# mean     32.300635
# std      22.682385
# min       8.000000
# 25%      20.000000
# 50%      29.000000
# 75%      40.000000
# max     265.000000

# %%
surveys[surveys.hindfoot_length.notna()]
# Out:
#            month  day  year  plot_id species_id sex  hindfoot_length  weight
# record_id
# 1              7   16  1977        2         NL   M             32.0     NaN
# 2              7   16  1977        3         NL   M             33.0     NaN
# 3              7   16  1977        2         DM   F             37.0     NaN
# 4              7   16  1977        7         DM   M             36.0     NaN
# 5              7   16  1977        3         DM   M             35.0     NaN
# ...          ...  ...   ...      ...        ...  ..              ...     ...
# 35541         12   31  2002       15         PB   F             24.0    31.0
# 35542         12   31  2002       15         PB   F             26.0    29.0
# 35543         12   31  2002       15         PB   F             27.0    34.0
# 35547         12   31  2002       10         RM   F             15.0    14.0
# 35548         12   31  2002        7         DO   M             36.0    51.0
#
# [31438 rows x 8 columns]

# %%
surveys.describe()
# Out:
#               month           day          year       plot_id  \
# count  35549.000000  35549.000000  35549.000000  35549.000000
# mean       6.477847     15.991195   1990.475231     11.397001
# std        3.396925      8.257366      7.493355      6.799406
# min        1.000000      1.000000   1977.000000      1.000000
# 25%        4.000000      9.000000   1984.000000      5.000000
# 50%        6.000000     16.000000   1990.000000     11.000000
# 75%       10.000000     23.000000   1997.000000     17.000000
# max       12.000000     31.000000   2002.000000     24.000000
#
#        hindfoot_length        weight
# count     31438.000000  32283.000000
# mean         29.287932     42.672428
# std           9.564759     36.631259
# min           2.000000      4.000000
# 25%          21.000000     20.000000
# 50%          32.000000     37.000000
# 75%          36.000000     48.000000
# max          70.000000    280.000000

# %%
df1=surveys[surveys.year==2000]
df2=surveys[surveys.year==2001]
df3=surveys[surveys.year==2002]

# %%
df1.describe()
# Out:
#              month          day    year      plot_id  hindfoot_length  \
# count  1552.000000  1552.000000  1552.0  1552.000000      1465.000000
# mean      6.242268    12.634021  2000.0    11.091495        26.130375
# std       3.200067    10.939377     0.0     6.842476         5.726347
# min       1.000000     1.000000  2000.0     1.000000         2.000000
# 25%       3.000000     3.000000  2000.0     4.000000        22.000000
# 50%       7.000000     6.000000  2000.0    11.000000        25.000000
# 75%       8.000000    25.000000  2000.0    17.000000        27.000000
# max      12.000000    30.000000  2000.0    24.000000        64.000000
#
#             weight
# count  1442.000000
# mean     32.394591
# std      23.626055
# min       8.000000
# 25%      20.000000
# 50%      29.000000
# 75%      39.000000
# max     265.000000

# %%
df2.describe()
# Out:
#              month          day    year      plot_id  hindfoot_length  \
# count  1610.000000  1610.000000  1610.0  1610.000000      1489.000000
# mean      7.576398    20.282609  2001.0    11.676398        27.140363
# std       3.036663     5.476341     0.0     6.798183         6.004684
# min       1.000000     3.000000  2001.0     1.000000        11.000000
# 25%       5.000000    17.000000  2001.0     6.000000        22.000000
# 50%       8.000000    22.000000  2001.0    12.000000        26.000000
# 75%      10.000000    25.000000  2001.0    17.000000        34.000000
# max      12.000000    27.000000  2001.0    24.000000        38.000000
#
#             weight
# count  1444.000000
# mean     36.469529
# std      28.728442
# min       6.000000
# 25%      21.000000
# 50%      31.000000
# 75%      44.000000
# max     280.000000

# %%
df3.describe()
# Out:
#              month          day    year      plot_id  hindfoot_length  \
# count  2229.000000  2229.000000  2229.0  2229.000000      2125.000000
# mean      7.084343    13.198744  2002.0    11.487663        27.242353
# std       3.513001     5.847898     0.0     6.742204         5.769105
# min       1.000000     5.000000  2002.0     1.000000         9.000000
# 25%       4.000000     9.000000  2002.0     6.000000        23.000000
# 50%       7.000000    13.000000  2002.0    12.000000        26.000000
# 75%      11.000000    16.000000  2002.0    17.000000        34.000000
# max      12.000000    31.000000  2002.0    24.000000        47.000000
#
#             weight
# count  2084.000000
# mean     35.641555
# std      25.787726
# min       5.000000
# 25%      22.000000
# 50%      31.000000
# 75%      45.000000
# max     248.000000

# %%
df200x=pd.concat([df1,df2,df3])

# %%
df200x.describe()
# Out:
#              month          day         year      plot_id  hindfoot_length  \
# count  5391.000000  5391.000000  5391.000000  5391.000000      5079.000000
# mean      6.988870    15.151734  2001.125580    11.429976        26.891711
# std       3.326883     8.293994     0.828077     6.790522         5.846137
# min       1.000000     1.000000  2000.000000     1.000000         2.000000
# 25%       4.000000     8.000000  2000.000000     6.000000        22.000000
# 50%       7.000000    15.000000  2001.000000    12.000000        26.000000
# 75%      10.000000    22.000000  2002.000000    17.000000        33.000000
# max      12.000000    31.000000  2002.000000    24.000000        64.000000
#
#             weight
# count  4970.000000
# mean     34.940040
# std      26.135898
# min       5.000000
# 25%      21.000000
# 50%      30.000000
# 75%      43.000000
# max     280.000000

# %%
df200x[df200x.year.isna()]
# Out:
# Empty DataFrame
# Columns: [month, day, year, plot_id, species_id, sex, hindfoot_length, weight]
# Index: []

# %%
df200x[df200x.hindfoot_length.isna()]
# Out:
#            month  day  year  plot_id species_id  sex  hindfoot_length  weight
# record_id
# 30189          1    8  2000       18         AH  NaN              NaN     NaN
# 30195          1    8  2000       18         SS  NaN              NaN     NaN
# 30217          1    8  2000       23         AH  NaN              NaN     NaN
# 30218          1    8  2000        7         AH  NaN              NaN     NaN
# 30274          1   10  2000       14         AH  NaN              NaN     NaN
# ...          ...  ...   ...      ...        ...  ...              ...     ...
# 35528         12   31  2002       13         US  NaN              NaN     NaN
# 35544         12   31  2002       15         US  NaN              NaN     NaN
# 35545         12   31  2002       15         AH  NaN              NaN     NaN
# 35546         12   31  2002       15         AH  NaN              NaN     NaN
# 35549         12   31  2002        5        NaN  NaN              NaN     NaN
#
# [312 rows x 8 columns]

# %%
df200x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5391 entries, 30159 to 35549
# Data columns (total 8 columns):
# month              5391 non-null int64
# day                5391 non-null int64
# year               5391 non-null int64
# plot_id            5391 non-null int64
# species_id         5241 non-null object
# sex                5084 non-null object
# hindfoot_length    5079 non-null float64
# weight             4970 non-null float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 379.1+ KB

# %%
pd.concat([df1,df2],axis=1)
# Out:
#            month  day    year  plot_id species_id  sex  hindfoot_length  \
# record_id
# 30159        1.0  8.0  2000.0      1.0         PP    F             22.0
# 30160        1.0  8.0  2000.0      1.0         DO    M             35.0
# 30161        1.0  8.0  2000.0      1.0         PP    F             21.0
# 30162        1.0  8.0  2000.0      1.0         DM    M             36.0
# 30163        1.0  8.0  2000.0      1.0         PP    M             20.0
# ...          ...  ...     ...      ...        ...  ...              ...
# 33316        NaN  NaN     NaN      NaN        NaN  NaN              NaN
# 33317        NaN  NaN     NaN      NaN        NaN  NaN              NaN
# 33318        NaN  NaN     NaN      NaN        NaN  NaN              NaN
# 33319        NaN  NaN     NaN      NaN        NaN  NaN              NaN
# 33320        NaN  NaN     NaN      NaN        NaN  NaN              NaN
#
#            weight  month   day    year  plot_id species_id  sex  \
# record_id
# ...

# %%
pd.concat([df1[['species_id','hindfoot_length']].reset_index(),
df2[['species_id','hindfoot_length']].reset_index()],axis=1)
# Out:
#       record_id species_id  hindfoot_length  record_id species_id  \
# 0       30159.0         PP             22.0      31711         PB
# 1       30160.0         DO             35.0      31712         DM
# 2       30161.0         PP             21.0      31713         PB
# 3       30162.0         DM             36.0      31714         DO
# 4       30163.0         PP             20.0      31715         OT
# ...         ...        ...              ...        ...        ...
# 1605        NaN        NaN              NaN      33316        NaN
# 1606        NaN        NaN              NaN      33317        NaN
# 1607        NaN        NaN              NaN      33318        NaN
# 1608        NaN        NaN              NaN      33319        NaN
# 1609        NaN        NaN              NaN      33320        NaN
#
#       hindfoot_length
# 0                26.0
# 1                37.0
# 2                29.0
# 3                34.0
# 4                20.0
# ...               ...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1552 entries, 30159 to 31710
# Data columns (total 8 columns):
# month              1552 non-null int64
# day                1552 non-null int64
# year               1552 non-null int64
# plot_id            1552 non-null int64
# species_id         1509 non-null object
# sex                1469 non-null object
# hindfoot_length    1465 non-null float64
# weight             1442 non-null float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 149.1+ KB

# %%
surveys.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35549 entries, 1 to 35549
# Data columns (total 8 columns):
# month              35549 non-null int64
# day                35549 non-null int64
# year               35549 non-null int64
# plot_id            35549 non-null int64
# species_id         34786 non-null object
# sex                33038 non-null object
# hindfoot_length    31438 non-null float64
# weight             32283 non-null float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 3.7+ MB

# %%
df=pd.read_csv('surveys.csv',header=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35549 entries, 0 to 35548
# Data columns (total 9 columns):
# record_id          35549 non-null int64
# month              35549 non-null int64
# day                35549 non-null int64
# year               35549 non-null int64
# plot_id            35549 non-null int64
# species_id         34786 non-null object
# sex                33038 non-null object
# hindfoot_length    31438 non-null float64
# weight             32283 non-null float64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 2.4+ MB

# %%
df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
sureysri=surveys.reset_index()

# %%
sureysri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35549 entries, 0 to 35548
# Data columns (total 9 columns):
# record_id          35549 non-null int64
# month              35549 non-null int64
# day                35549 non-null int64
# year               35549 non-null int64
# plot_id            35549 non-null int64
# species_id         34786 non-null object
# sex                33038 non-null object
# hindfoot_length    31438 non-null float64
# weight             32283 non-null float64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 2.4+ MB

# %%
sureysri.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
df1m=df1[['species_id','hindfoot_length']].reset_index().drop('record_id',axis=1)

# %%
df1m.head()
# Out:
#   species_id  hindfoot_length
# 0         PP             22.0
# 1         DO             35.0
# 2         PP             21.0
# 3         DM             36.0
# 4         PP             20.0

# %%
df2m=df2[['species_id','hindfoot_length']].reset_index().drop('record_id',axis=1)

# %%
df2m.head()
# Out:
#   species_id  hindfoot_length
# 0         PB             26.0
# 1         DM             37.0
# 2         PB             29.0
# 3         DO             34.0
# 4         OT             20.0

# %%
pd.merge(left=df1m,\
         right=df2m, \
         left_on='species_id', \
         right_on='species_id')
# Out:
#        species_id  hindfoot_length_x  hindfoot_length_y
# 0              PP               22.0               20.0
# 1              PP               22.0               21.0
# 2              PP               22.0               22.0
# 3              PP               22.0               23.0
# 4              PP               22.0               22.0
# ...           ...                ...                ...
# 512301         PE               20.0               20.0
# 512302         PE               20.0               20.0
# 512303         PE               20.0               20.0
# 512304         PE               20.0               20.0
# 512305         PE               20.0               20.0
#
# [512306 rows x 3 columns]

# %%
df1m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1552 entries, 0 to 1551
# Data columns (total 2 columns):
# species_id         1509 non-null object
# hindfoot_length    1465 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 24.4+ KB

# %%
df2m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1610 entries, 0 to 1609
# Data columns (total 2 columns):
# species_id         1540 non-null object
# hindfoot_length    1489 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 25.3+ KB

# %%
1552*1610
# Out:
# 2498720

# %%
pd.merge(left=df1m,\
         right=df2m, \
         how='left', \
         left_on='species_id', \
         right_on='species_id')
# Out:
#        species_id  hindfoot_length_x  hindfoot_length_y
# 0              PP               22.0               20.0
# 1              PP               22.0               21.0
# 2              PP               22.0               22.0
# 3              PP               22.0               23.0
# 4              PP               22.0               22.0
# ...           ...                ...                ...
# 512304        NaN                NaN                NaN
# 512305        NaN                NaN                NaN
# 512306        NaN                NaN                NaN
# 512307        NaN                NaN                NaN
# 512308        NaN                NaN                NaN
#
# [512309 rows x 3 columns]

# %%
df=pd.merge(left=df1m,\
         right=df2m, \
         how='left', \
         left_on='species_id', \
         right_on='species_id')

# %%
df[df.species_id.notna()]
# Out:
#        species_id  hindfoot_length_x  hindfoot_length_y
# 0              PP               22.0               20.0
# 1              PP               22.0               21.0
# 2              PP               22.0               22.0
# 3              PP               22.0               23.0
# 4              PP               22.0               22.0
# ...           ...                ...                ...
# 512094         OT               20.0               21.0
# 512095         OT               20.0                NaN
# 512096         OT               20.0               20.0
# 512097         OT               20.0               19.0
# 512098         OT               20.0               20.0
#
# [509299 rows x 3 columns]

# %%
import pandas_profiling

# %%
surveys.profile_report()
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.3.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...

# %%
import sqlite3

# %%
import pandas as pd

# %%
con = sqlite3.connect("surveys.sqlite3")

# %%
df = pd.read_sql('select * from surveys',con=con)

# %%
df.head()
# Out:
#   record_id month day  year plot_id species_id sex hindfoot_length weight
# 0         1     7  16  1977       2         NL   M              32
# 1         2     7  16  1977       3         NL   M              33
# 2         3     7  16  1977       2         DM   F              37
# 3         4     7  16  1977       7         DM   M              36
# 4         5     7  16  1977       3         DM   M              35
