# %%
import pandas as pd
import numpy as np

# %%
cols=['DATES',
      'Q-E',
'ZN-E',
'PH-E',
'DBO-E',
'DQO-E',
'SS-E',
'SSV-E',
'SED-E',
'COND-',
'PH-P',
'DBO-P',
'SS-P',
'SSV-P',
'SED-P',
'COND-',
'PH-D',
'DBO-D',
'DQO-D',
'SS-D ',
'SSV-D',
'SED-D',
'COND-D',
'PH-S',
'DBO-S',
'DQO-S',
'SS-S',
'SSV-S',
'SED-S',
'COND-S',
'RD-DBO-P',
'RD-SS-P',
'RD-SED-P',
'RD-DBO-S',
'RD-DQO-S',
'RD-DBO-G',
'RD-DQO-G',
'RD-SS-G',
'RD-SED-G']

# %%
df = pd.read_csv('/Users/akaghzi/Downloads/water-treatment.data', header=None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 527 entries, 0 to 526
# Data columns (total 39 columns):
# 0     527 non-null object
# 1     527 non-null object
# 2     527 non-null object
# 3     527 non-null float64
# 4     527 non-null object
# 5     527 non-null object
# 6     527 non-null object
# 7     527 non-null object
# 8     527 non-null object
# 9     527 non-null int64
# 10    527 non-null float64
# 11    527 non-null object
# 12    527 non-null int64
# 13    527 non-null object
# 14    527 non-null object
# 15    527 non-null int64
# 16    527 non-null float64
# 17    527 non-null object
# 18    527 non-null object
# 19    527 non-null object
# 20    527 non-null object
# 21    527 non-null object
# 22    527 non-null int64
# 23    527 non-null object
# 24    527 non-null object
# 25    527 non-null object
# 26    527 non-null object
# 27    527 non-null object
# 28    527 non-null object
# 29    527 non-null object
# 30    527 non-null object
# ...

# %%
df.columns=cols

# %%
df.set_index('DATES', inplace=True)

# %%
df.head()
# Out:
#             Q-E  ZN-E  PH-E DBO-E DQO-E SS-E SSV-E SED-E  COND-  PH-P  ...  \
# DATES                                                                  ...
# D-1/3/90  44101  1.50   7.8     ?   407  166  66.3   4.5   2110   7.9  ...
# D-2/3/90  39024  3.00   7.7     ?   443  214  69.2   6.5   2660   7.7  ...
# D-4/3/90  32229  5.00   7.6     ?   528  186  69.9   3.4   1666   7.7  ...
# D-5/3/90  35023  3.50   7.9   205   588  192  65.6   4.5   2430   7.8  ...
# D-6/3/90  36924  1.50   8.0   242   496  176  64.8   4.0   2110   7.9  ...
#
#          COND-S  RD-DBO-P RD-SS-P RD-SED-P  RD-DBO-S  RD-DQO-S RD-DBO-G  \
# DATES
# D-1/3/90   2000         ?    58.8     95.5         ?      70.0        ?
# D-2/3/90   2590         ?    60.7     94.8         ?      80.8        ?
# D-4/3/90   1888         ?    58.2     95.6         ?      52.9        ?
# D-5/3/90   1840      33.1    64.2     95.3      87.3      72.3     90.2
# D-6/3/90   2120         ?    62.7     95.6         ?      71.0     92.1
# ...

# %%
df.replace('?',np.nan, inplace=True)

# %%
df=df.astype('float64')

# %%
df.head()
# Out:
#               Q-E  ZN-E  PH-E  DBO-E  DQO-E   SS-E  SSV-E  SED-E   COND-  \
# DATES
# D-1/3/90  44101.0   1.5   7.8    NaN  407.0  166.0   66.3    4.5  2110.0
# D-2/3/90  39024.0   3.0   7.7    NaN  443.0  214.0   69.2    6.5  2660.0
# D-4/3/90  32229.0   5.0   7.6    NaN  528.0  186.0   69.9    3.4  1666.0
# D-5/3/90  35023.0   3.5   7.9  205.0  588.0  192.0   65.6    4.5  2430.0
# D-6/3/90  36924.0   1.5   8.0  242.0  496.0  176.0   64.8    4.0  2110.0
#
#           PH-P  ...  COND-S  RD-DBO-P  RD-SS-P  RD-SED-P  RD-DBO-S  RD-DQO-S  \
# DATES           ...
# D-1/3/90   7.9  ...  2000.0       NaN     58.8      95.5       NaN      70.0
# D-2/3/90   7.7  ...  2590.0       NaN     60.7      94.8       NaN      80.8
# D-4/3/90   7.7  ...  1888.0       NaN     58.2      95.6       NaN      52.9
# D-5/3/90   7.8  ...  1840.0      33.1     64.2      95.3      87.3      72.3
# D-6/3/90   7.9  ...  2120.0       NaN     62.7      95.6       NaN      71.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 527 entries, D-1/3/90 to D-30/8/91
# Data columns (total 38 columns):
# Q-E         509 non-null float64
# ZN-E        524 non-null float64
# PH-E        527 non-null float64
# DBO-E       504 non-null float64
# DQO-E       521 non-null float64
# SS-E        526 non-null float64
# SSV-E       516 non-null float64
# SED-E       502 non-null float64
# COND-       527 non-null float64
# PH-P        527 non-null float64
# DBO-P       487 non-null float64
# SS-P        527 non-null float64
# SSV-P       516 non-null float64
# SED-P       503 non-null float64
# COND-       527 non-null float64
# PH-D        527 non-null float64
# DBO-D       499 non-null float64
# DQO-D       518 non-null float64
# SS-D        525 non-null float64
# SSV-D       514 non-null float64
# SED-D       502 non-null float64
# COND-D      527 non-null float64
# PH-S        526 non-null float64
# DBO-S       504 non-null float64
# DQO-S       509 non-null float64
# ...

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans()

# %%
df.head()
# Out:
#               Q-E  ZN-E  PH-E  DBO-E  DQO-E   SS-E  SSV-E  SED-E   COND-  \
# DATES
# D-1/3/90  44101.0   1.5   7.8    NaN  407.0  166.0   66.3    4.5  2110.0
# D-2/3/90  39024.0   3.0   7.7    NaN  443.0  214.0   69.2    6.5  2660.0
# D-4/3/90  32229.0   5.0   7.6    NaN  528.0  186.0   69.9    3.4  1666.0
# D-5/3/90  35023.0   3.5   7.9  205.0  588.0  192.0   65.6    4.5  2430.0
# D-6/3/90  36924.0   1.5   8.0  242.0  496.0  176.0   64.8    4.0  2110.0
#
#           PH-P  ...  COND-S  RD-DBO-P  RD-SS-P  RD-SED-P  RD-DBO-S  RD-DQO-S  \
# DATES           ...
# D-1/3/90   7.9  ...  2000.0       NaN     58.8      95.5       NaN      70.0
# D-2/3/90   7.7  ...  2590.0       NaN     60.7      94.8       NaN      80.8
# D-4/3/90   7.7  ...  1888.0       NaN     58.2      95.6       NaN      52.9
# D-5/3/90   7.8  ...  1840.0      33.1     64.2      95.3      87.3      72.3
# D-6/3/90   7.9  ...  2120.0       NaN     62.7      95.6       NaN      71.0
#
# ...

# %%
df.replace(np.nan,df.mean(),inplace=True)

# %%
df.head()
# Out:
#               Q-E  ZN-E  PH-E       DBO-E  DQO-E   SS-E  SSV-E  SED-E   COND-  \
# DATES
# D-1/3/90  44101.0   1.5   7.8  188.714286  407.0  166.0   66.3    4.5  2110.0
# D-2/3/90  39024.0   3.0   7.7  188.714286  443.0  214.0   69.2    6.5  2660.0
# D-4/3/90  32229.0   5.0   7.6  188.714286  528.0  186.0   69.9    3.4  1666.0
# D-5/3/90  35023.0   3.5   7.9  205.000000  588.0  192.0   65.6    4.5  2430.0
# D-6/3/90  36924.0   1.5   8.0  242.000000  496.0  176.0   64.8    4.0  2110.0
#
#           PH-P  ...  COND-S   RD-DBO-P  RD-SS-P  RD-SED-P   RD-DBO-S  \
# DATES           ...
# D-1/3/90   7.9  ...  2000.0  39.085806     58.8      95.5  83.448049
# D-2/3/90   7.7  ...  2590.0  39.085806     60.7      94.8  83.448049
# D-4/3/90   7.7  ...  1888.0  39.085806     58.2      95.6  83.448049
# D-5/3/90   7.8  ...  1840.0  33.100000     64.2      95.3  87.300000
# D-6/3/90   7.9  ...  2120.0  39.085806     62.7      95.6  83.448049
#
# ...

# %%
model.fit(df)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=8, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
df.corr()
# Out:
#                Q-E      ZN-E      PH-E     DBO-E     DQO-E      SS-E  \
# Q-E       1.000000  0.036150  0.137804 -0.235947 -0.332162 -0.010152
# ZN-E      0.036150  1.000000 -0.010403 -0.008020  0.080761  0.090619
# PH-E      0.137804 -0.010403  1.000000  0.209100  0.180473 -0.047036
# DBO-E    -0.235947 -0.008020  0.209100  1.000000  0.547312  0.135572
# DQO-E    -0.332162  0.080761  0.180473  0.547312  1.000000  0.286550
# SS-E     -0.010152  0.090619 -0.047036  0.135572  0.286550  1.000000
# SSV-E    -0.323816 -0.095286  0.186794  0.251783  0.257402 -0.543511
# SED-E    -0.122108  0.079506  0.054660  0.267851  0.426201  0.574159
# COND-    -0.081707  0.055507  0.272851  0.215679  0.309944  0.083125
# PH-P      0.154394  0.000067  0.902909  0.199085  0.174184 -0.100730
# DBO-P    -0.211985  0.034685  0.214626  0.712042  0.525960  0.121232
# SS-P     -0.027382  0.031271 -0.030850  0.130156  0.236171  0.876729
# SSV-P    -0.301792 -0.065373  0.188741  0.211254  0.214638 -0.499093
# ...

# %%
df
# Out:
#                Q-E  ZN-E  PH-E       DBO-E  DQO-E   SS-E  SSV-E     SED-E  \
# DATES
# D-1/3/90   44101.0  1.50   7.8  188.714286  407.0  166.0   66.3  4.500000
# D-2/3/90   39024.0  3.00   7.7  188.714286  443.0  214.0   69.2  6.500000
# D-4/3/90   32229.0  5.00   7.6  188.714286  528.0  186.0   69.9  3.400000
# D-5/3/90   35023.0  3.50   7.9  205.000000  588.0  192.0   65.6  4.500000
# D-6/3/90   36924.0  1.50   8.0  242.000000  496.0  176.0   64.8  4.000000
# ...            ...   ...   ...         ...    ...    ...    ...       ...
# D-26/8/91  32723.0  0.16   7.7   93.000000  252.0  176.0   56.8  2.300000
# D-27/8/91  33535.0  0.32   7.8  192.000000  346.0  172.0   68.6  4.000000
# D-28/8/91  32922.0  0.30   7.4  139.000000  367.0  180.0   64.4  3.000000
# D-29/8/91  32190.0  0.30   7.3  200.000000  545.0  258.0   65.1  4.000000
# D-30/8/91  30488.0  0.21   7.5  152.000000  300.0  132.0   69.7  4.593825
#
# ...

# %%
import matplotlib.pyplot as plt
Nc = range(1, 20)
kmeans = [KMeans(n_clusters=i) for i in Nc]
score = [kmeans[i].fit(df).score(df) for i in range(len(kmeans))]
plt.plot(Nc,score)
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show()

# %%
kmeans
# Out:
# [KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#         n_clusters=1, n_init=10, n_jobs=None, precompute_distances='auto',
#         random_state=None, tol=0.0001, verbose=0),
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#         n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#         random_state=None, tol=0.0001, verbose=0),
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#         n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#         random_state=None, tol=0.0001, verbose=0),
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#         n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#         random_state=None, tol=0.0001, verbose=0),
#  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#         n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
# ...

# %%
score
# Out:
# [-22739907422.71575,
#  -8400634043.2191105,
#  -5175532767.01817,
#  -3499338113.864484,
#  -2480585689.57646,
#  -1878712634.0869403,
#  -1361387109.456139,
#  -1133635996.8721073,
#  -964052339.4829192,
#  -842823469.4382274,
#  -740708788.77058,
#  -674402767.4400406,
#  -635483403.2423158,
#  -593577014.1680813,
#  -547886447.5968149,
#  -525045968.47446305,
#  -505350733.54809487,
#  -460762535.3010151,
#  -439993237.2104003]

# %%
clusters=model.predict(df)

# %%
df['cluster_id']=clusters

# %%
df.head()

# %%
_

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df.iloc[:,0], df.iloc[:,1], c=model.labels_.astype(float))

# %%
import seaborn as sns

# %%
plt.figure(figsize=[16,8])
sns.swarmplot(df.cluster_id,df['Q-E'])

# %%
plt.figure(figsize=[16,8])
sns.swarmplot(df['cluster_id'],df['RD-SED-G'])

# %%
from yellowbrick.cluster import KElbowVisualizer
visualizer = KElbowVisualizer(model, k=(4,12))
visualizer.fit(df)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure
